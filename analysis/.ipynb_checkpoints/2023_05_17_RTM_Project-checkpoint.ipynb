# %%
from tools.base import *
from tools.ddmtd import *
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from time import sleep 
from copy import deepcopy
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib
matplotlib.style.available
matplotlib.style.use(['seaborn-darkgrid'])
# plt.rcParams['figure.figsize'] = [4, 3]
plt.rcParams['figure.dpi'] = 300
# Out:
# /tmp/ipykernel_2190160/4264932307.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   matplotlib.style.use(['seaborn-darkgrid'])

# %%
freq=160

# %%
bin(6)
# Out:
# '0b110'

# %%
#Generate column names
NUM_WORDS = 32
column_names = []
for i in range(1,NUM_WORDS+1):
    column_names.append(f"edge{i}")
    column_names.append(f"ddmtd{i}")
    
# pd.set_option('max_columns', None)
# pd.set_option('max_rows', 100)

# %%
# freq=160
# board_num = 4
# server="board3_trenz"
# rpi_server="board3_pi"
# !../RPi/config_pll.sh {rpi_server} ../RPi/ 2021_10_05_Si5344H/OCXO/Si5344H-RevD-Registers_{freq}M.h 2021_10_05_Si5344H/PLL/Si5344H-RevD-Registers_{freq}M_100K.h {board_num}

# %%
server="kria"

# %%
0b11
# Out:
# 3

# %%
# def get_data(step,channel =5,folder="",aq_iter = 100):
#     data_folder = f"data_files/{folder}/c{channel}_data_step_{str(step).zfill(3)}/"
#     !mkdir -p {data_folder}
#     !../acq_software/run_atPi.sh ../acq_software/ {step} {channel} {rpi_server}
#     !../acq_software/run_atKria.sh ../acq_software/ {aq_iter} {server}
#     !sshpass -p "root" rsync -aP {server}:data_acq/data_files/ddmtd1.txt ./{data_folder}/ddmtd1.txt
#     !sshpass -p "root" rsync -aP {server}:data_acq/data_files/ddmtd2.txt ./{data_folder}/ddmtd2.txt
#     !sshpass -p "root" rsync -aP {server}:data_acq/data_files/ddmtd3.txt ./{data_folder}/ddmtd3.txt


def get_data(fine_delay,coarse_delay ,channel =5,folder="",aq_iter = 100):
    data_folder = f"data_files/{folder}/c{channel}_fstep_{str(fine_delay).zfill(3)}_cstep_{str(coarse_delay).zfill(3)}"
    # !mkdir -p {data_folder}
    # !../acq_software/run_atKria.sh ../acq_software/ {aq_iter} {server}
    # !rsync -aP {server}:data_acq/data_files/ddmtd1.txt ./{data_folder}/ddmtd1.txt
    # !rsync -aP {server}:data_acq/data_files/ddmtd2.txt ./{data_folder}/ddmtd2.txt
    # !rsync -aP {server}:data_acq/data_files/ddmtd3.txt ./{data_folder}/ddmtd3.txt
        
        
#def debug_spi(fine_delay,coarse_delay ,channel =5,folder="",aq_iter = 100):
#    data_folder = f"data_files/{folder}/c{channel}_fstep_{str(fine_delay).zfill(3)}_cstep_{str(coarse_delay).zfill(3)}"
#    !mkdir -p {data_folder}
#    !../acq_software/run_atPi.sh ../acq_software/ {fine_delay} {coarse_delay} {channel} {rpi_server}
#     !../acq_software/run_atKria.sh ../acq_software/ {aq_iter} {server}
#     !rsync -aP {server}:data_acq/data_files/ddmtd1.txt ./{data_folder}/ddmtd1.txt
#     !rsync -aP {server}:data_acq/data_files/ddmtd2.txt ./{data_folder}/ddmtd2.txt
#     !rsync -aP {server}:data_acq/data_files/ddmtd3.txt ./{data_folder}/ddmtd3.txt
        
        
        

def plot_data(fine_delay=0,coarse_delay=0,channel =10,folder="",freq=160*10**6,data_stream = (1,3),draw=False):   
    df = data2df(fine_delay
             ,coarse_delay
             ,channel=channel
             ,folder=folder
             ,freq = freq
             ,data_stream = data_stream
            )
#     popt,p_err = df.drawTIE(save_name='',bns=None,fit=True, sep="TIE_FALL")
    popt,p_err = df.drawTIE(save_name='',bns=None,fit=True, sep="",draw=draw)
    


    return (popt[1]*1000,p_err[1]*1000)
    
    

def plot_tie(tie):
    f,ax = plt.subplots(figsize=(8,6))
    
    ax.errorbar(tie[0],tie[1],yerr=tie[2],fmt='o',
#                         color='red',
                        capsize=5,
                        ecolor='black'
                        ,label=f'ODD'
                       )
#     ax.errorbar(tie[0],tie[3],yerr=tie[4],fmt='o',
# #                         color='red',
#                         capsize=5,
#                         ecolor='black'
#                         ,label=f'EVEN'
#                        )
    plt.xlabel("Delay cell index", fontsize=15)
    plt.ylabel("TIE [ps] staggered", fontsize=15)
    plt.legend(loc="upper right")
    plt.gca().grid()
    
def data2df(fine_delay=0,coarse_delay=0,channel =5,folder="",freq=160*10**6, data_stream = (1,3)):
    data_folder = f"data_files/{folder}/c{channel}_fstep_{str(fine_delay).zfill(3)}_cstep_{str(coarse_delay).zfill(3)}"
    dv1= pd.read_csv(f"{data_folder}/ddmtd1.txt",sep=",",header=0 ,skiprows=0,names=column_names[0:16])
    dv2= pd.read_csv(f"{data_folder}/ddmtd2.txt",sep=",",header=0 ,skiprows=0,names=column_names[16:32])
    dv3= pd.read_csv(f"{data_folder}/ddmtd3.txt",sep=",",header=0 ,skiprows=0,names=column_names[32:48])
    dv = pd.concat((dv1,dv2,dv3),axis=1)  
#     dv = dv1
#     df = deepcopy(dv[(dv.T != 0).any()])
#     df = df.reset_index(drop=1)ore loop

    df = deepcopy(dv)
#     return df 
#     df = df[df.ddmt d3!=2147483647].reset_index(drop=1).drop([0,1,2])    
#     df.iloc[0,:]=0
#     return df
    data = ddmtd(deepcopy(df),q=1,channel=data_stream)
    data.N=100000
    data.INPUT_FREQ = freq
    data.Recalc()
    return data 

#def config_dcps(step,channel):
#    !../acq_software/run_atPi.sh ../acq_software/ {step} {channel} {rpi_server}


#Nishant remove sshpass and use scp -r
#Just use rsync -aP ub
def get_data_debug(step,channel =5,folder="",aq_iter = 100,sleep_time=20000):
    data_folder = f"data_files/{folder}/c{channel}_data_step_{str(step).zfill(3)}/"
    # !mkdir -p {data_folder}
    # !../acq_software/run_atKria.sh ../acq_software/ {aq_iter} {server} {sleep_time}
    # !rsync -aP {server}:data_acq/data_files/ddmtd1.txt ./{data_folder}/ddmtd1.txt
    # !rsync -aP {server}:data_acq/data_files/ddmtd2.txt ./{data_folder}/ddmtd2.txt
    # !rsync -aP {server}:data_acq/data_files/ddmtd3.txt ./{data_folder}/ddmtd3.txt
        
        
def copy_data(step,channel =5,folder="",aq_iter = 100,sleep_time=20000):
    data_folder = f"data_files/{folder}/c{channel}_data_step_{str(step).zfill(3)}/"
    # !mkdir -p {data_folder}
    # !rsync -aP {server}:data_acq/data_files/ddmtd1.txt ./{data_folder}/ddmtd1.txt
    # !rsync -aP {server}:data_acq/data_files/ddmtd2.txt ./{data_folder}/ddmtd2.txt
    # !rsync -aP {server}:data_acq/data_files/ddmtd3.txt ./{data_folder}/ddmtd3.txt
# Out:
#   Cell In[9], line 79
#     FAIL Data Transfer
#          ^
# SyntaxError: invalid syntax

# %%
#Nishant commenting out
#board_num = 4

# for i in range(100):
#!../RPi/config_pll.sh {rpi_server} ../RPi/ 2021_10_05_Si5344/OCXO/Si5344-RevD-Registers_{freq}M.h 2021_10_05_Si5344/PLL/Si5344-RevD-Registers_{freq}M_100K.h {board_num}

# board_num=3
# !../RPi/config_pll.sh {rpi_server} ../RPi/ 2021_10_05_Si5344H/OCXO/Si5344H-RevD-Registers_{freq}M.h 2021_10_05_Si5344H/PLL/Si5344H-RevD-Registers_{freq}M_100K.h {board_num}
# Out:
# Board Number {board_num} chosen; make sure this is the correct board
# cp: cannot stat '../RPi/si5344_config/2021_10_05_Si5344/PLL/Si5344-RevD-Registers_{freq}M_100K.h': No such file or directory
# cp: cannot stat '../RPi/si5344_config/2021_10_05_Si5344/OCXO/Si5344-RevD-Registers_{freq}M.h': No such file or directory
# ssh: Could not resolve hostname {rpi_server}: Name or service not known
# rsync: connection unexpectedly closed (0 bytes received so far) [sender]
# rsync error: unexplained error (code 255) at io.c(235) [sender=3.1.3]
# ssh: Could not resolve hostname {rpi_server}: Name or service not known

# %%
folder_name = f"2022_04_14_{freq}MHz"

# %%
# for i in range(100):
#     debug_spi(0,16,channel=4,folder=folder_name,aq_iter=100)
#     sleep(.1)
# #     debug_spi(0,16,channel=5,folder=folder_name,aq_iter=100)
# #     sleep(.1)

# %%
# for i in range(6):

#     debug_spi(0,16,channel=i,folder=folder_name,aq_iter=100)
#     sleep(1)

# %%
#channel
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 channel
#
# NameError: name 'channel' is not defined

# %%
#Change date to current date of executing the script
folder_name = f"2022_05_01_{freq}MHz"
channel = 0
for i in range(0,32):
    get_data(i,0,channel=channel,folder=folder_name,aq_iter=100)
# Out:
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: 0 (Ok)
# bram: loaded to slot 0
# -bash: line 13: 262195 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 262452 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 262707 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 262962 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 263213 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 263469 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 263727 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 263987 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 264248 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 264508 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 264765 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 265017 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 265274 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 265529 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 265786 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 266043 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 266304 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 266560 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 266817 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 267075 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 267329 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 267586 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 267837 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 268107 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 268364 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 268621 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 268882 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 269135 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 269391 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 269649 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 269917 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 270168 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)

# %%
get_data(24,0,channel=channel,folder=folder_name,aq_iter=100)
# Out:
# Running & Compiling Section
# Compiling get_data_bram
# get_data_bram compiled
# Running get_data_bram
# remove from slot 0 returns: -1 (Error)
# bram: loaded to slot 0
# -bash: line 13: 270424 Segmentation fault      sudo ./get_data_bram 100
# remove from slot 0 returns: 0 (Ok)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)
# receiving incremental file list
# rsync: [sender] change_dir "/home/ubuntu/data_acq/data_files" failed: No such file or directory (2)
# rsync error: some files/attrs were not transferred (see previous errors) (code 23) at main.c(1677) [Receiver=3.1.3]
# rsync: [Receiver] write error: Broken pipe (32)

# %%
X  = []
Y  = []
Ye = []
for f_step in range(0,32):
    try:
        tie,tie_err = plot_data(f_step
             ,0
             ,channel=channel
             ,folder=folder_name
             ,freq = freq*10**6
             ,data_stream = (2,10)
             ,draw=False
                )
        X.append(f_step)
        Y.append(tie)
        Ye.append(tie_err)
    except:
        print(f"{f_step} lost")
# Out:
# 0 lost
# 1 lost
# 2 lost
# 3 lost
# 4 lost
# 5 lost
# 6 lost
# 7 lost
# 8 lost
# 9 lost
# 10 lost
# 11 lost
# 12 lost
# 13 lost
# 14 lost
# 15 lost
# 16 lost
# 17 lost
# 18 lost
# 19 lost
# 20 lost
# 21 lost
# 22 lost
# 23 lost
# 24 lost
# 25 lost
# 26 lost
# 27 lost
# 28 lost
# 29 lost
# 30 lost
# 31 lost

# %%
x = np.asarray(X)
y = np.abs(np.asarray(Y) - Y[0])
y_err = np.asarray(Ye)
f,ax = plt.subplots()

popt,pcov = np.polyfit(x,y,1,cov=True)
p_e = np.sqrt(np.diag(pcov))

ax.scatter(x,y)
ax.plot(x,popt[0]*x+popt[1],color="r",linestyle='--',label=f"Channel 0 \n{popt[0]:4.3}+/- {p_e[0]:4.2} [ps/step]")
ax.set_ylabel("Delay [ps]")
ax.set_xlabel("Fine Step")
ax.legend(loc="upper left",fontsize=10)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 x = np.asarray(X)
# ----> 2 y = np.abs(np.asarray(Y) - Y[0])
#       3 y_err = np.asarray(Ye)
#       4 f,ax = plt.subplots()
#
# IndexError: list index out of range

# %%
# channel = 0
# get_data(0,0,channel=channel,folder=folder_name,aq_iter=100)

# %%
folder_name = f"2022_05_01_{freq}MHz"
channel = 0
for i in range(0,32):
    get_data(0,i,channel=channel,folder=folder_name,aq_iter=100)

# %%
# tie,tie_err = plot_data(0
#                  ,1
#                  ,channel=channel
#                  ,folder=folder_name
#                  ,freq = freq*10**6
#                  ,data_stream = (11,7)
#                  ,draw=True
#                     )

# %%
folder_name = f"2022_05_01_{freq}MHz"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 folder_name = f"2022_05_01_{freq}MHz"
#
# NameError: name 'freq' is not defined

# %%
get_data(0,7,channel=channel,folder=folder_name,aq_iter=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 get_data(0,7,channel=channel,folder=folder_name,aq_iter=100)
#
# NameError: name 'get_data' is not defined

# %%
X  = []
Y  = []
Ye = []
for c_step in range(0,32):
    try:
        tie,tie_err = plot_data(0
             ,c_step
             ,channel=channel
             ,folder=folder_name
             ,freq = freq*10**6
             ,data_stream = (2,10)
             ,draw=False
                )
        X.append(c_step)
        Y.append(tie)
        Ye.append(tie_err)
    except:
        print(f"{c_step} lost")
# Out:
# 0 lost
# 1 lost
# 2 lost
# 3 lost
# 4 lost
# 5 lost
# 6 lost
# 7 lost
# 8 lost
# 9 lost
# 10 lost
# 11 lost
# 12 lost
# 13 lost
# 14 lost
# 15 lost
# 16 lost
# 17 lost
# 18 lost
# 19 lost
# 20 lost
# 21 lost
# 22 lost
# 23 lost
# 24 lost
# 25 lost
# 26 lost
# 27 lost
# 28 lost
# 29 lost
# 30 lost
# 31 lost

# %%
np.diff(Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 np.diff(Y)
#
# NameError: name 'np' is not defined

# %%
Y
# Out:
# []

# %%
x = np.asarray(X)
y = np.abs(np.asarray(Y) - Y[0])
y_err = np.asarray(Ye)
f,ax = plt.subplots()

popt,pcov = np.polyfit(x,y,1,cov=True)
p_e = np.sqrt(np.diag(pcov))

ax.scatter(x,y)
ax.plot(x,popt[0]*x+popt[1],color="r",linestyle='--',label=f"Channel 0 \n{popt[0]:4.3}+/- {p_e[0]:4.2} [ps/step]")
ax.set_ylabel("Delay [ps]")
ax.set_xlabel("Coarse Step")
ax.legend(loc="upper left",fontsize=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 x = np.asarray(X)
#       2 y = np.abs(np.asarray(Y) - Y[0])
#       3 y_err = np.asarray(Ye)
#
# NameError: name 'np' is not defined

# %%
X  = []
Y  = []
Ye = []
for c_step in (0,1,2,4,8,16):
    try:
        tie,tie_err = plot_data(0
             ,c_step
             ,channel=channel
             ,folder=folder_name
             ,freq = freq*10**6
             ,data_stream = (2,10)
             ,draw=False
                )
        X.append(c_step)
        Y.append(tie)
        Ye.append(tie_err)
    except:
        print(f"{c_step} lost")
# Out:
# 0 lost
# 1 lost
# 2 lost
# 4 lost
# 8 lost
# 16 lost

# %%
np.abs(Y-Y[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 np.abs(Y-Y[0])
#
# NameError: name 'np' is not defined

# %%
data = {}
# folder_name = f"2022_04_12_{freq}MHz"
folder_name = f"2022_05_01_{freq}MHz"


for chan in (3,6,7,10,11):
    X  = []
    Y  = []
    Ye = []
    for c_step in (0,16):
        try:
            tie,tie_err = plot_data(0
                 ,c_step
                 ,channel=channel
                 ,folder=folder_name
                 ,freq = freq*10**6
                 ,data_stream = (2,chan)
                 ,draw=False
                    )
            X.append(c_step)
            Y.append(tie)
            Ye.append(tie_err)
        except:
            print(f"{c_step} lost")
    
    data[f"chan{chan}"] = np.asarray((X,Y,Ye))
#2,3
#6,7
#10,11
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 data = {}
#       2 # folder_name = f"2022_04_12_{freq}MHz"
# ----> 3 folder_name = f"2022_05_01_{freq}MHz"
#       6 for chan in (3,6,7,10,11):
#       7     X  = []
#
# NameError: name 'freq' is not defined

# %%
# !open .

# %%
for i in data.keys():
    X = data[i][0]*8
    Y = data[i][1]
#     print(Y)
    try:
        print(f"{i}\t{np.abs(np.diff(Y))[0]:5.5f}ps")
    except:
        print(f"{i}   lost")

# %%
# # f,ax = plt.subplots(figsize=(8,6))
# for i in data.keys():
#     f,ax = plt.subplots(figsize=(8,6))

#     X = data[i][0]*8
#     Y = data[i][1]
# #     Ye = data[i][2]
#     ax.scatter(X,Y)
    
#     print(i)
#     ax.set_xlabel("ps")

# %%
# data["chan3"][1]

# %%
X = np.asarray(data).T[0]
Y = np.asarray(data).T[1]
Ye = np.asarray(data).T[2]



plt.scatter(X[X>20],Y[X>20])
plt.scatter(X,Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 X = np.asarray(data).T[0]
#       2 Y = np.asarray(data).T[1]
#       3 Ye = np.asarray(data).T[2]
#
# NameError: name 'np' is not defined

# %%
data = []
for c_step in range(0,32):
    try:
        tie,tie_err = plot_data(0
                 ,c_step
                 ,channel=10
                 ,folder=folder_name
                 ,freq = freq*10**6
                 ,data_stream = (2,6)
                 ,draw=False
                    )
        data.append((c_step,tie,tie_err))
    except:
        print(f"{c_step} lost")
#2,3
#6,7
#10,11
# Out:
# 0 lost
# 1 lost
# 2 lost
# 3 lost
# 4 lost
# 5 lost
# 6 lost
# 7 lost
# 8 lost
# 9 lost
# 10 lost
# 11 lost
# 12 lost
# 13 lost
# 14 lost
# 15 lost
# 16 lost
# 17 lost
# 18 lost
# 19 lost
# 20 lost
# 21 lost
# 22 lost
# 23 lost
# 24 lost
# 25 lost
# 26 lost
# 27 lost
# 28 lost
# 29 lost
# 30 lost
# 31 lost

# %%
# folder_name = f"2022_04_14_{freq}MHz"
# for i in range(0,32):
#     get_data(i,0,channel=10,folder=folder_name,aq_iter=100)
